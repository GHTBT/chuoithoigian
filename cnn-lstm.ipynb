# %%
import pandas as pd
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from numpy import array
from numpy import hstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_percentage_error
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
from keras.layers import Flatten
from keras.layers import TimeDistributed
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Conv1D,MaxPooling1D

# %%
local='D://a_trash//MSFT.csv'
df_raw=pd.read_csv(local)
df_raw.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-01-04  222.529999  223.000000  214.809998  217.690002  211.605301
# 1  2021-01-05  217.259995  218.520004  215.699997  217.899994  211.809433
# 2  2021-01-06  212.169998  216.490005  211.940002  212.250000  206.317352
# 3  2021-01-07  214.039993  219.339996  213.710007  218.289993  212.188538
# 4  2021-01-08  218.679993  220.580002  217.029999  219.619995  213.481339
#
#      Volume
# 0  37130100
# 1  23823000
# 2  35930700
# 3  27694500
# 4  22956200

# %%
# path = Path(local)
# file_name = path.stem

# figure = go.Figure(data=[go.Candlestick(x=df_raw["Date"],
#                                         open=df_raw["Open"], high=df_raw["High"],
#                                         low=df_raw["Low"], close=df_raw["Close"])])
# figure.update_layout(title = file_name+" Stock Price Analysis", xaxis_rangeslider_visible=False)
# figure.show()

# %%
#Chuyển đổi cột 'date' thành datetime
df_raw['Date'] = pd.to_datetime(df_raw['Date'])

# Tạo cột 'month_day' chỉ chứa tháng và ngày
df_raw['year-month-day'] = df_raw['Date'].dt.strftime('%Y-%m-%d')

# %%
average_values = df_raw.groupby('year-month-day')[['Open', 'High', 'Low','Close']].mean().reset_index()

# %%
df_raw.head(8)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2021-01-04  222.529999  223.000000  214.809998  217.690002  211.605301
# 1 2021-01-05  217.259995  218.520004  215.699997  217.899994  211.809433
# 2 2021-01-06  212.169998  216.490005  211.940002  212.250000  206.317352
# 3 2021-01-07  214.039993  219.339996  213.710007  218.289993  212.188538
# 4 2021-01-08  218.679993  220.580002  217.029999  219.619995  213.481339
# 5 2021-01-11  218.470001  218.910004  216.729996  217.490005  211.410889
# 6 2021-01-12  216.500000  217.100006  213.320007  214.929993  208.922440
# 7 2021-01-13  214.020004  216.759995  213.929993  216.339996  210.293045
#
#      Volume year-month-day
# 0  37130100     2021-01-04
# 1  23823000     2021-01-05
# 2  35930700     2021-01-06
# 3  27694500     2021-01-07
# 4  22956200     2021-01-08
# 5  23031300     2021-01-11
# 6  23249300     2021-01-12
# 7  20087100     2021-01-13

# %%
average_values.head()
# Out:
#   year-month-day        Open        High         Low       Close
# 0     2021-01-04  222.529999  223.000000  214.809998  217.690002
# 1     2021-01-05  217.259995  218.520004  215.699997  217.899994
# 2     2021-01-06  212.169998  216.490005  211.940002  212.250000
# 3     2021-01-07  214.039993  219.339996  213.710007  218.289993
# 4     2021-01-08  218.679993  220.580002  217.029999  219.619995

# %%
dataset = average_values.drop(columns=['year-month-day']).to_numpy()
print(dataset.shape)
# Out:
# (753, 4)

# %%
# Tính toán ma trận tương quan
correlation_matrix = average_values.drop(columns=['year-month-day']).corr()

# In ma trận tương quan
print(correlation_matrix)

# Vẽ ma trận tương quan
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Ma trận tương quan giữa các cổ phiếu')
plt.show()
# Out:
#            Open      High       Low     Close
# Open   1.000000  0.998023  0.997853  0.994981
# High   0.998023  1.000000  0.997551  0.997754
# Low    0.997853  0.997551  1.000000  0.997872
# Close  0.994981  0.997754  0.997872  1.000000

# %%
#chia tập dữ liệu 1 bộ train và test
dt_Train,dt_Test = train_test_split(dataset,test_size=0.2,shuffle=False)

# %%
print('số lượng mẫu cho tập train: {}'.format(dt_Train.size))
print('số lượng mẫu cho tập train: {}'.format(dt_Test.size))
# Out:
# số lượng mẫu cho tập train: 2408
# số lượng mẫu cho tập train: 604

# %%
### multivariate lstm model

# %%
# hàm chia timestep
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
n_steps = 4
X, y = split_sequences(dt_Train, n_steps)
print('chọn timesteps là 3 nên số mẫu dữ liệu train được đưa vào mô hình có dạng:')
print('mẫu                  : {} lần lượt là (số lượng mẫu, n_steps, 3 features open, high, low)'.format(X.shape))
print('giá cổ phếu cuối cùng: {}'.format(y.shape))
# Out:
# chọn timesteps là 3 nên số mẫu dữ liệu train được đưa vào mô hình có dạng:
# mẫu                  : (599, 4, 3) lần lượt là (số lượng mẫu, n_steps, 3 features open, high, low)
# giá cổ phếu cuối cùng: (599,)

# %%
n_features = 3
n_seq = 2
n_steps = 2 # substeps
X = X.reshape((X.shape[0], n_seq, n_steps, n_features))
# define model
model = Sequential()
model.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), input_shape=(None, n_steps, n_features)))
model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model.add(TimeDistributed(Flatten()))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(X, y, epochs=2500, verbose=0)
# Out:
# D:\code\anaconda4-22-2024\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
X_val, y_target = split_sequences(dt_Test, 4)

# %%
x_input = X_val.reshape((X_val.shape[0], 2, 2, 3))
yhat = model.predict(x_input, verbose=0)

# %%
print("----đánh giá độ đo----")
print("MAE: %.5f" %mae(yhat,y_target))
print("MSE: %.5f" %mse(yhat,y_target))
print("NSE: %.5f" %(1-(np.sum((y_target-yhat)**2)/np.sum((y_target-np.mean(y_target))**2))))
print("R2: %.5f " %r2_score(y_target,yhat))
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_target,np.array(yhat).reshape(-1, 1))
print("mape:",mape)
# Out:
# ----đánh giá độ đo----
# MAE: 1.98720
# MSE: 6.52680
# NSE: -289.46411
# R2: 0.98319
# mape: 0.005791459731811794

# %%
time=average_values['year-month-day'].iloc[-len(yhat):]

# %%
plt.figure(figsize=(20, 6))
plt.plot(time, y_target, label='Thực tế', marker='o')
plt.plot(time, yhat, label='Dự đoán', marker='x')
plt.xlabel('Thời gian')
plt.ylabel('Giá trị')
plt.title('So sánh giá trị dự đoán và thực tế')
plt.xticks(rotation=90)  # Xoay nhãn trục x để dễ đọc
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
